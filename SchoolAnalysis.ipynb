# %%
import pandas as pd
import numpy as np

# %%
schools = "c:\\@work\\gtbcdata\\hw4pd\\schools.csv"
students = "c:\\@work\\gtbcdata\\hw4pd\\students.csv"

# %%
schoolData = pd.read_csv(schools)
studentData = pd.read_csv(students)

# %%
schoolData
# Out:
#     School ID            school_name      type  size   budget
# 0           0      Huang High School  District  2917  1910635
# 1           1   Figueroa High School  District  2949  1884411
# 2           2    Shelton High School   Charter  1761  1056600
# 3           3  Hernandez High School  District  4635  3022020
# 4           4    Griffin High School   Charter  1468   917500
# 5           5     Wilson High School   Charter  2283  1319574
# 6           6    Cabrera High School   Charter  1858  1081356
# 7           7     Bailey High School  District  4976  3124928
# 8           8     Holden High School   Charter   427   248087
# 9           9       Pena High School   Charter   962   585858
# 10         10     Wright High School   Charter  1800  1049400
# 11         11  Rodriguez High School  District  3999  2547363
# 12         12    Johnson High School  District  4761  3094650
# 13         13       Ford High School  District  2739  1763916
# ...

# %%
schoolData['school_name']
# Out:
# 0         Huang High School
# 1      Figueroa High School
# 2       Shelton High School
# 3     Hernandez High School
# 4       Griffin High School
# 5        Wilson High School
# 6       Cabrera High School
# 7        Bailey High School
# 8        Holden High School
# 9          Pena High School
# 10       Wright High School
# 11    Rodriguez High School
# 12      Johnson High School
# 13         Ford High School
# 14       Thomas High School
# Name: school_name, dtype: object

# %%
studentData.head(2)
# Out:
#    Student ID  student_name gender grade        school_name  reading_score  \
# 0           0  Paul Bradley      M   9th  Huang High School             66
# 1           1  Victor Smith      M  12th  Huang High School             94
#
#    math_score
# 0          79
# 1          61

# %%
schoolData.count()
# Out:
# School ID      15
# school_name    15
# type           15
# size           15
# budget         15
# dtype: int64

# %%
studentData.count()
# Out:
# Student ID       39170
# student_name     39170
# gender           39170
# grade            39170
# school_name      39170
# reading_score    39170
# math_score       39170
# dtype: int64

# %%
studentData.head(2)
# Out:
#    Student ID  student_name gender grade        school_name  reading_score  \
# 0           0  Paul Bradley      M   9th  Huang High School             66
# 1           1  Victor Smith      M  12th  Huang High School             94
#
#    math_score
# 0          79
# 1          61

# %%
totalData = pd.merge(studentData, schoolData, how="left", on=["school_name", "school_name"])

# %%
totalData.head(2)
# Out:
#    Student ID  student_name gender grade        school_name  reading_score  \
# 0           0  Paul Bradley      M   9th  Huang High School             66
# 1           1  Victor Smith      M  12th  Huang High School             94
#
#    math_score  School ID      type  size   budget
# 0          79          0  District  2917  1910635
# 1          61          0  District  2917  1910635

# %%
len(schoolData)
# Out:
# 15

# %%
schoolData["budget"].sum()
# Out:
# 24649428

# %%
#av math score
mathAverage=studentData["math_score"].mean()

# %%
readAverage=studentData["reading_score"].mean()

# %%
passingMath=sum(studentData['math_score']>= 70)
passingMath
# Out:
# 29370

# %%
mathPassingPercent=passingMath/len(studentData)*100
mathPassingPercent
# Out:
# 74.9808526933878

# %%
passingReading=sum(studentData['reading_score']>= 70)
passingReading
# Out:
# 33610

# %%
readPassPercent=passingReading/len(studentData)*100
readPassPercent
# Out:
# 85.80546336482001

# %%
overallPassPercent=(mathAverage + readAverage)/2 # this matches your example, but dont' this is right? shouldn't this be based on math and reading passing %?
overallPassPercent
# Out:
# 80.43160582078121

# %%
districtSummary=pd.DataFrame({"Total Schools":[len(schoolData)],
                            "Total Students":[len(studentData)],
                             "Total Budget":[schoolData["budget"].sum()], 
                              "Average Math Score":[studentData["math_score"].mean()],
                              "Average Reading Score":[studentData["reading_score"].mean()],
                              "Math Passing %":[mathPassingPercent],
                              "Reading Passing %":[readPassPercent],
                              "Overall Passing %":[overallPassPercent]
                             })
districtSummary
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0             15           39170      24649428           78.985371
#
#    Average Reading Score  Math Passing %  Reading Passing %  Overall Passing %
# 0               81.87784       74.980853          85.805463          80.431606

# %%
districtSummary['Math Passing %'] = districtSummary['Math Passing %'].map("{0:,.2f}".format)
districtSummary['Reading Passing %'] = districtSummary['Reading Passing %'].map("{0:,.2f}".format)
districtSummary['Overall Passing %'] = districtSummary['Overall Passing %'].map("{0:,.2f}".format)
districtSummary['Average Math Score'] = districtSummary['Average Math Score'].map("{0:,.2f}".format)
districtSummary['Average Reading Score'] = districtSummary['Average Reading Score'].map("{0:,.2f}".format)
# why do these throw an error when running a second time.. how do i overcome?

# %%
districtSummary
# Out:
#    Total Schools  Total Students  Total Budget Average Math Score  \
# 0             15           39170      24649428              78.99
#
#   Average Reading Score Math Passing % Reading Passing % Overall Passing %
# 0                 81.88          74.98             85.81             80.43

# %%
numberOfStudents=totalData['school_name'].value_counts()

# %%
schoolSummary=pd.DataFrame(totalData['school_name'].value_counts())
schoolSummary.reset_index(inplace=True)

schoolSummary.columns=['School Name', 'Number of Students']
#len(schoolSummary.columns)
#schoolSummary=schoolSummary.drop('level_0',axis=1)
schoolSummary
# Out:
#               School Name  Number of Students
# 0      Bailey High School                4976
# 1     Johnson High School                4761
# 2   Hernandez High School                4635
# 3   Rodriguez High School                3999
# 4    Figueroa High School                2949
# 5       Huang High School                2917
# 6        Ford High School                2739
# 7      Wilson High School                2283
# 8     Cabrera High School                1858
# 9      Wright High School                1800
# 10    Shelton High School                1761
# 11     Thomas High School                1635
# 12    Griffin High School                1468
# 13       Pena High School                 962
# 14     Holden High School                 427

# %%
#schoolSummary['School Type']=totalData['type']

# %%
#schoolSummary=schoolSummary.drop('School Type',axis=1)

# %%
schoolType=schoolData[['school_name','type']]

# %%
schoolSummary=schoolSummary.merge(schoolType, left_on='School Name', right_on='school_name', how='inner')

# %%
schoolSummary
# Out:
#               School Name  Number of Students            school_name      type
# 0      Bailey High School                4976     Bailey High School  District
# 1     Johnson High School                4761    Johnson High School  District
# 2   Hernandez High School                4635  Hernandez High School  District
# 3   Rodriguez High School                3999  Rodriguez High School  District
# 4    Figueroa High School                2949   Figueroa High School  District
# 5       Huang High School                2917      Huang High School  District
# 6        Ford High School                2739       Ford High School  District
# 7      Wilson High School                2283     Wilson High School   Charter
# 8     Cabrera High School                1858    Cabrera High School   Charter
# 9      Wright High School                1800     Wright High School   Charter
# 10    Shelton High School                1761    Shelton High School   Charter
# ...

# %%
schoolSummary=schoolSummary.drop('school_name',axis=1)

# %%
schoolSummary.rename(columns={'type':'Type'})
# Out:
#               School Name  Number of Students      Type
# 0      Bailey High School                4976  District
# 1     Johnson High School                4761  District
# 2   Hernandez High School                4635  District
# 3   Rodriguez High School                3999  District
# 4    Figueroa High School                2949  District
# 5       Huang High School                2917  District
# 6        Ford High School                2739  District
# 7      Wilson High School                2283   Charter
# 8     Cabrera High School                1858   Charter
# 9      Wright High School                1800   Charter
# 10    Shelton High School                1761   Charter
# 11     Thomas High School                1635   Charter
# 12    Griffin High School                1468   Charter
# 13       Pena High School                 962   Charter
# 14     Holden High School                 427   Charter

# %%
schoolSummary=schoolSummary[['School Name','type','Number of Students']]
#schoolSummary.columns

# %%
schoolSummary=schoolSummary.rename(columns={'type':'Type'})

# %%
schoolSummary
# Out:
#               School Name      Type  Number of Students
# 0      Bailey High School  District                4976
# 1     Johnson High School  District                4761
# 2   Hernandez High School  District                4635
# 3   Rodriguez High School  District                3999
# 4    Figueroa High School  District                2949
# 5       Huang High School  District                2917
# 6        Ford High School  District                2739
# 7      Wilson High School   Charter                2283
# 8     Cabrera High School   Charter                1858
# 9      Wright High School   Charter                1800
# 10    Shelton High School   Charter                1761
# 11     Thomas High School   Charter                1635
# 12    Griffin High School   Charter                1468
# 13       Pena High School   Charter                 962
# 14     Holden High School   Charter                 427

# %%
schoolBudget=pd.DataFrame(schoolData[['school_name','budget']])

# %%
schoolBudget
# Out:
#               school_name   budget
# 0       Huang High School  1910635
# 1    Figueroa High School  1884411
# 2     Shelton High School  1056600
# 3   Hernandez High School  3022020
# 4     Griffin High School   917500
# 5      Wilson High School  1319574
# 6     Cabrera High School  1081356
# 7      Bailey High School  3124928
# 8      Holden High School   248087
# 9        Pena High School   585858
# 10     Wright High School  1049400
# 11  Rodriguez High School  2547363
# 12    Johnson High School  3094650
# 13       Ford High School  1763916
# 14     Thomas High School  1043130

# %%
#districtSummary['Average Reading Score'] = districtSummary['Average Reading Score'].map("{0:,.2f}".format)
#schoolBudget['budget'] = 
#schoolBudget['budget']=schoolBudget['budget'].map("${0:,.2f}".format)

#schoolBudget.index('school_name')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Budget'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-285-e23803e16a2f> in <module>()
# ...

# %%
#temp_dataframe['PPI'].replace('PPI/','',regex=True,inplace=True)
#schoolBudget['budget']=schoolBudget.loc['budget'].replace('$','',regex=True, inplace=True)
schoolBudget.index('school_name')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-261-2d735e243c7d> in <module>()
#       1 #temp_dataframe['PPI'].replace('PPI/','',regex=True,inplace=True)
#       2 #schoolBudget['budget']=schoolBudget.loc['budget'].replace('$','',regex=True, inplace=True)
# ----> 3 schoolBudget.index('school_name')
#
# TypeError: 'RangeIndex' object is not callable

# %%
schoolSummary=schoolSummary.merge(schoolBudget, left_on='School Name', right_on='school_name', how='inner')

# %%
#schoolSummary['$ Per Student Budget']=schoolSummary['budget']/schoolSummary['Number of Students']
schoolSummary
# Out:
#               School Name      Type  Number of Students         Budget  \
# 0      Bailey High School  District                4976  $3,124,928.00
# 1     Johnson High School  District                4761  $3,094,650.00
# 2   Hernandez High School  District                4635  $3,022,020.00
# 3   Rodriguez High School  District                3999  $2,547,363.00
# 4    Figueroa High School  District                2949  $1,884,411.00
# 5       Huang High School  District                2917  $1,910,635.00
# 6        Ford High School  District                2739  $1,763,916.00
# 7      Wilson High School   Charter                2283  $1,319,574.00
# 8     Cabrera High School   Charter                1858  $1,081,356.00
# 9      Wright High School   Charter                1800  $1,049,400.00
# 10    Shelton High School   Charter                1761  $1,056,600.00
# 11     Thomas High School   Charter                1635  $1,043,130.00
# ...

# %%
#i didn't properly create budget per student and had to go back and create
#schoolSummary=schoolSummary.drop('School Type',axis=1)
#schoolSummary=schoolSummary.drop('budget_y',axis=1)
schoolSummary=schoolSummary.rename(columns={'budget_x':'Budget'})

# %%
schoolSummary=schoolSummary.drop('school_name_y',axis=1)
#schoolSummary

# %%
schoolSummary['Budget']=schoolSummary['Budget'].map("${0:,.2f}".format)
#schoolSummary.columns

# %%
schoolSummary=schoolSummary[['School Name','Type','Number of Students','Budget','$ Per Student Budget',
                             'Average Math Score',
                            'Average Reading Score',
                            '% Passing Math',
                            'Reading Passing %',
                            'Overall Passing %']]

# %%
schoolSummary
# Out:
#               School Name      Type  Number of Students         budget
# 0      Bailey High School  District                4976  $3,124,928.00
# 1     Johnson High School  District                4761  $3,094,650.00
# 2   Hernandez High School  District                4635  $3,022,020.00
# 3   Rodriguez High School  District                3999  $2,547,363.00
# 4    Figueroa High School  District                2949  $1,884,411.00
# 5       Huang High School  District                2917  $1,910,635.00
# 6        Ford High School  District                2739  $1,763,916.00
# 7      Wilson High School   Charter                2283  $1,319,574.00
# 8     Cabrera High School   Charter                1858  $1,081,356.00
# 9      Wright High School   Charter                1800  $1,049,400.00
# 10    Shelton High School   Charter                1761  $1,056,600.00
# 11     Thomas High School   Charter                1635  $1,043,130.00
# ...

# %%
schoolSummary=schoolSummary.rename(columns={'budget':'Budget'})

# %%
schoolSummary
# Out:
#               School Name      Type  Number of Students         Budget
# 0      Bailey High School  District                4976  $3,124,928.00
# 1     Johnson High School  District                4761  $3,094,650.00
# 2   Hernandez High School  District                4635  $3,022,020.00
# 3   Rodriguez High School  District                3999  $2,547,363.00
# 4    Figueroa High School  District                2949  $1,884,411.00
# 5       Huang High School  District                2917  $1,910,635.00
# 6        Ford High School  District                2739  $1,763,916.00
# 7      Wilson High School   Charter                2283  $1,319,574.00
# 8     Cabrera High School   Charter                1858  $1,081,356.00
# 9      Wright High School   Charter                1800  $1,049,400.00
# 10    Shelton High School   Charter                1761  $1,056,600.00
# 11     Thomas High School   Charter                1635  $1,043,130.00
# ...

# %%
averageMathBySchool=studentData[['school_name','math_score']]

averageMathBySchool= averageMathBySchool.groupby(['school_name']).mean()
averageMathBySchool
# Out:
#                        math_score
# school_name
# Bailey High School      77.048432
# Cabrera High School     83.061895
# Figueroa High School    76.711767
# Ford High School        77.102592
# Griffin High School     83.351499
# Hernandez High School   77.289752
# Holden High School      83.803279
# Huang High School       76.629414
# Johnson High School     77.072464
# Pena High School        83.839917
# Rodriguez High School   76.842711
# Shelton High School     83.359455
# Thomas High School      83.418349
# Wilson High School      83.274201
# Wright High School      83.682222

# %%
#schoolSummary=schoolSummary.merge(schoolBudget, left_on='School Name', right_on='school_name', how='inner')
schoolSummary=schoolSummary.merge(averageMathBySchool, left_on='School Name', right_on='school_name', how='inner')

# %%
schoolSummary
# Out:
#               School Name      Type  Number of Students         Budget  \
# 0      Bailey High School  District                4976  $3,124,928.00
# 1     Johnson High School  District                4761  $3,094,650.00
# 2   Hernandez High School  District                4635  $3,022,020.00
# 3   Rodriguez High School  District                3999  $2,547,363.00
# 4    Figueroa High School  District                2949  $1,884,411.00
# 5       Huang High School  District                2917  $1,910,635.00
# 6        Ford High School  District                2739  $1,763,916.00
# 7      Wilson High School   Charter                2283  $1,319,574.00
# 8     Cabrera High School   Charter                1858  $1,081,356.00
# 9      Wright High School   Charter                1800  $1,049,400.00
# 10    Shelton High School   Charter                1761  $1,056,600.00
# 11     Thomas High School   Charter                1635  $1,043,130.00
# ...

# %%
schoolSummary=schoolSummary.rename(columns={'math_score':'Average Math Score'})

# %%
schoolSummary
# Out:
#               School Name      Type  Number of Students         Budget  \
# 0      Bailey High School  District                4976  $3,124,928.00
# 1     Johnson High School  District                4761  $3,094,650.00
# 2   Hernandez High School  District                4635  $3,022,020.00
# 3   Rodriguez High School  District                3999  $2,547,363.00
# 4    Figueroa High School  District                2949  $1,884,411.00
# 5       Huang High School  District                2917  $1,910,635.00
# 6        Ford High School  District                2739  $1,763,916.00
# 7      Wilson High School   Charter                2283  $1,319,574.00
# 8     Cabrera High School   Charter                1858  $1,081,356.00
# 9      Wright High School   Charter                1800  $1,049,400.00
# 10    Shelton High School   Charter                1761  $1,056,600.00
# 11     Thomas High School   Charter                1635  $1,043,130.00
# ...

# %%
averageReadBySchool=studentData[['school_name','reading_score']]

# %%
averageReadBySchool.head()
# Out:
#                       reading_score
# school_name
# Bailey High School        81.033963
# Cabrera High School       83.975780
# Figueroa High School      81.158020
# Ford High School          80.746258
# Griffin High School       83.816757

# %%
averageReadBySchool= averageReadBySchool.groupby(['school_name']).mean()
averageReadBySchool.head()
# Out:
#                       reading_score
# school_name
# Bailey High School        81.033963
# Cabrera High School       83.975780
# Figueroa High School      81.158020
# Ford High School          80.746258
# Griffin High School       83.816757

# %%
#schoolSummary=schoolSummary.merge(averageMathBySchool, left_on='School Name', right_on='school_name', how='inner')
schoolSummary=schoolSummary.merge(averageReadBySchool, left_on='School Name', right_on='school_name', how='inner')

# %%
schoolSummary
# Out:
#               School Name      Type  Number of Students         Budget  \
# 0      Bailey High School  District                4976  $3,124,928.00
# 1     Johnson High School  District                4761  $3,094,650.00
# 2   Hernandez High School  District                4635  $3,022,020.00
# 3   Rodriguez High School  District                3999  $2,547,363.00
# 4    Figueroa High School  District                2949  $1,884,411.00
# 5       Huang High School  District                2917  $1,910,635.00
# 6        Ford High School  District                2739  $1,763,916.00
# 7      Wilson High School   Charter                2283  $1,319,574.00
# 8     Cabrera High School   Charter                1858  $1,081,356.00
# 9      Wright High School   Charter                1800  $1,049,400.00
# 10    Shelton High School   Charter                1761  $1,056,600.00
# 11     Thomas High School   Charter                1635  $1,043,130.00
# ...

# %%
schoolSummary=schoolSummary.rename(columns={'reading_score':'Average Reading Score'})

# %%
schoolSummary
# Out:
#               School Name      Type  Number of Students         Budget  \
# 0      Bailey High School  District                4976  $3,124,928.00
# 1     Johnson High School  District                4761  $3,094,650.00
# 2   Hernandez High School  District                4635  $3,022,020.00
# 3   Rodriguez High School  District                3999  $2,547,363.00
# 4    Figueroa High School  District                2949  $1,884,411.00
# 5       Huang High School  District                2917  $1,910,635.00
# 6        Ford High School  District                2739  $1,763,916.00
# 7      Wilson High School   Charter                2283  $1,319,574.00
# 8     Cabrera High School   Charter                1858  $1,081,356.00
# 9      Wright High School   Charter                1800  $1,049,400.00
# 10    Shelton High School   Charter                1761  $1,056,600.00
# 11     Thomas High School   Charter                1635  $1,043,130.00
# ...

# %%
#mathPassingPercent=passingMath/len(studentData)*100
#passingMath=sum(studentData['math_score']>= 70)
#averageReadBySchool= averageReadBySchool.groupby(['school_name']).mean()
#averageReadBySchool

#mathPassingPercentbySchool= sum(studentData['math_score']>= 70)
#readbySchool=studentData[['school_name','reading_score']]
mathbySchool=studentData[['school_name','math_score']]
totalStudentsbySchool=mathbySchool.groupby(['school_name']).count()
totalStudentsbySchool
# Out:
#                        math_score
# school_name
# Bailey High School           4976
# Cabrera High School          1858
# Figueroa High School         2949
# Ford High School             2739
# Griffin High School          1468
# Hernandez High School        4635
# Holden High School            427
# Huang High School            2917
# Johnson High School          4761
# Pena High School              962
# Rodriguez High School        3999
# Shelton High School          1761
# Thomas High School           1635
# Wilson High School           2283
# Wright High School           1800

# %%
mathbySchool=studentData[['school_name','math_score']]

# %%
mathPassingbySchool=mathbySchool[mathbySchool >=70]

# %%
mathPassingbySchool.head()
# Out:
#          school_name  math_score
# 0  Huang High School        79.0
# 1  Huang High School         NaN
# 2  Huang High School         NaN
# 3  Huang High School         NaN
# 4  Huang High School        84.0

# %% [markdown]
# mathPassingbySchool.dropna()

# %%
mathPassingbySchool=mathPassingbySchool.dropna()

# %%
mathPassingbySchool=mathPassingbySchool.groupby(['school_name']).count()

# %%
#schoolSummary=schoolSummary.merge(averageReadBySchool, left_on='School Name', right_on='school_name', how='inner')

#mathPassingbySchool.columns
mathPassingbySchool
# Out:
#                        math_score
# school_name
# Bailey High School           3318
# Cabrera High School          1749
# Figueroa High School         1946
# Ford High School             1871
# Griffin High School          1371
# Hernandez High School        3094
# Holden High School            395
# Huang High School            1916
# Johnson High School          3145
# Pena High School              910
# Rodriguez High School        2654
# Shelton High School          1653
# Thomas High School           1525
# Wilson High School           2143
# Wright High School           1680

# %%
mathPassingbySchool=mathPassingbySchool.rename(columns={'math_score':'passingCount'})

# %%
totalStudentsbySchool=totalStudentsbySchool.rename(columns={'math_score':'totalCount'})

# %%
totalStudentsbySchool.columns
# Out:
# Index(['totalCount'], dtype='object')

# %%
mathTotalAndPassing=mathPassingbySchool.merge(totalStudentsbySchool, left_on='school_name', right_on='school_name', how='inner')

# %%
mathTotalAndPassing
# Out:
#                        passingCount  totalCount
# school_name
# Bailey High School             3318        4976
# Cabrera High School            1749        1858
# Figueroa High School           1946        2949
# Ford High School               1871        2739
# Griffin High School            1371        1468
# Hernandez High School          3094        4635
# Holden High School              395         427
# Huang High School              1916        2917
# Johnson High School            3145        4761
# Pena High School                910         962
# Rodriguez High School          2654        3999
# Shelton High School            1653        1761
# Thomas High School             1525        1635
# Wilson High School             2143        2283
# Wright High School             1680        1800

# %%
mathTotalAndPassing['% Passing Math']=mathTotalAndPassing['passingCount']/mathTotalAndPassing['totalCount']*100

# %%
mathTotalAndPassing
# Out:
#                        passingCount  totalCount  % Passing Math
# school_name
# Bailey High School             3318        4976       66.680064
# Cabrera High School            1749        1858       94.133477
# Figueroa High School           1946        2949       65.988471
# Ford High School               1871        2739       68.309602
# Griffin High School            1371        1468       93.392371
# Hernandez High School          3094        4635       66.752967
# Holden High School              395         427       92.505855
# Huang High School              1916        2917       65.683922
# Johnson High School            3145        4761       66.057551
# Pena High School                910         962       94.594595
# Rodriguez High School          2654        3999       66.366592
# Shelton High School            1653        1761       93.867121
# Thomas High School             1525        1635       93.272171
# ...

# %%
mathTotalAndPassing.dtypes
# Out:
# passingCount        int64
# totalCount          int64
# % Passing Math    float64
# dtype: object

# %%
#mathTotalAndPassing['% Passing Math'] = mathTotalAndPassing['% Passing Math'].map("{0:,.2f}%".format)
#better to format at the end cuz these formating commands are hard to undo?

# %%
mathTotalAndPassing
# Out:
#                        passingCount  totalCount  % Passing Math
# school_name
# Bailey High School             3318        4976       66.680064
# Cabrera High School            1749        1858       94.133477
# Figueroa High School           1946        2949       65.988471
# Ford High School               1871        2739       68.309602
# Griffin High School            1371        1468       93.392371
# Hernandez High School          3094        4635       66.752967
# Holden High School              395         427       92.505855
# Huang High School              1916        2917       65.683922
# Johnson High School            3145        4761       66.057551
# Pena High School                910         962       94.594595
# Rodriguez High School          2654        3999       66.366592
# Shelton High School            1653        1761       93.867121
# Thomas High School             1525        1635       93.272171
# ...

# %%
passingMathbySchool=pd.DataFrame(mathTotalAndPassing['% Passing Math'])

# %%
passingMathbySchool.head(2)
# Out:
#                      % Passing Math
# school_name
# Bailey High School        66.680064
# Cabrera High School       94.133477

# %%
schoolSummary=schoolSummary.merge(passingMathbySchool, left_on='School Name', right_on='school_name', how='inner')

# %%
schoolSummary.head(9)
# Out:
#              School Name      Type  Number of Students         Budget  \
# 0     Bailey High School  District                4976  $3,124,928.00
# 1    Johnson High School  District                4761  $3,094,650.00
# 2  Hernandez High School  District                4635  $3,022,020.00
# 3  Rodriguez High School  District                3999  $2,547,363.00
# 4   Figueroa High School  District                2949  $1,884,411.00
# 5      Huang High School  District                2917  $1,910,635.00
# 6       Ford High School  District                2739  $1,763,916.00
# 7     Wilson High School   Charter                2283  $1,319,574.00
# 8    Cabrera High School   Charter                1858  $1,081,356.00
#
#    Average Math Score  Average Reading Score  % Passing Math
# 0           77.048432              81.033963       66.680064
# 1           77.072464              80.966394       66.057551
# 2           77.289752              80.934412       66.752967
# ...

# %%
readbySchool=studentData[['school_name','reading_score']]

# %%
readbySchool.head(2)
# Out:
#          school_name  reading_score
# 0  Huang High School             66
# 1  Huang High School             94

# %%
readPassingbySchool=readbySchool[readbySchool >=70]

# %%
#mathPassingbySchool=mathPassingbySchool.dropna()
readPassingbySchool=readPassingbySchool.dropna()

# %%
#mathPassingbySchool=mathPassingbySchool.groupby(['school_name']).count()
readPassingbySchool=readPassingbySchool.groupby(['school_name']).count()

# %%
readPassingbySchool['totalCount'] =totalStudentsbySchool['totalCount']

# %%
readPassingbySchool
# Out:
#                        reading_score  totalCount
# school_name
# Bailey High School              4077        4976
# Cabrera High School             1803        1858
# Figueroa High School            2381        2949
# Ford High School                2172        2739
# Griffin High School             1426        1468
# Hernandez High School           3748        4635
# Holden High School               411         427
# Huang High School               2372        2917
# Johnson High School             3867        4761
# Pena High School                 923         962
# Rodriguez High School           3208        3999
# Shelton High School             1688        1761
# Thomas High School              1591        1635
# Wilson High School              2204        2283
# Wright High School              1739        1800

# %%
#readPassingbySchool['Reading Passing %']= 
readPassingbySchool['Reading Passing %']=readPassingbySchool['reading_score']/readPassingbySchool['totalCount']

# %%
readPassingbySchool['Reading Passing %']=readPassingbySchool['Reading Passing %']*100

# %%
readPassingbySchoolPercent= pd.DataFrame(readPassingbySchool['Reading Passing %'])

# %%
readPassingbySchoolPercent
# Out:
#                        Reading Passing %
# school_name
# Bailey High School             81.933280
# Cabrera High School            97.039828
# Figueroa High School           80.739234
# Ford High School               79.299014
# Griffin High School            97.138965
# Hernandez High School          80.862999
# Holden High School             96.252927
# Huang High School              81.316421
# Johnson High School            81.222432
# Pena High School               95.945946
# Rodriguez High School          80.220055
# Shelton High School            95.854628
# Thomas High School             97.308869
# Wilson High School             96.539641
# Wright High School             96.611111

# %%
schoolSummary=schoolSummary.merge(readPassingbySchoolPercent, left_on='School Name', right_on='school_name', how='inner')

# %%
schoolSummary
# Out:
#               School Name      Type  Number of Students         Budget  \
# 0      Bailey High School  District                4976  $3,124,928.00
# 1     Johnson High School  District                4761  $3,094,650.00
# 2   Hernandez High School  District                4635  $3,022,020.00
# 3   Rodriguez High School  District                3999  $2,547,363.00
# 4    Figueroa High School  District                2949  $1,884,411.00
# 5       Huang High School  District                2917  $1,910,635.00
# 6        Ford High School  District                2739  $1,763,916.00
# 7      Wilson High School   Charter                2283  $1,319,574.00
# 8     Cabrera High School   Charter                1858  $1,081,356.00
# 9      Wright High School   Charter                1800  $1,049,400.00
# 10    Shelton High School   Charter                1761  $1,056,600.00
# 11     Thomas High School   Charter                1635  $1,043,130.00
# ...

# %%
schoolSummary["Overall Passing %"]=(schoolSummary['% Passing Math']+schoolSummary['Reading Passing %'])/2

# %%
schoolSummary
# Out:
#               School Name      Type  Number of Students         Budget  \
# 0      Bailey High School  District                4976  $3,124,928.00
# 1     Johnson High School  District                4761  $3,094,650.00
# 2   Hernandez High School  District                4635  $3,022,020.00
# 3   Rodriguez High School  District                3999  $2,547,363.00
# 4    Figueroa High School  District                2949  $1,884,411.00
# 5       Huang High School  District                2917  $1,910,635.00
# 6        Ford High School  District                2739  $1,763,916.00
# 7      Wilson High School   Charter                2283  $1,319,574.00
# 8     Cabrera High School   Charter                1858  $1,081,356.00
# 9      Wright High School   Charter                1800  $1,049,400.00
# 10    Shelton High School   Charter                1761  $1,056,600.00
# 11     Thomas High School   Charter                1635  $1,043,130.00
# ...

# %%
# Sort results in descending order
#merged_df = merged_df.sort_values(["% Recommend"], ascending=False).round(2)
topSchools = schoolSummary.sort_values(["Overall Passing %"], ascending=False)

# %%
topSchools.head(5)
# Out:
#             School Name     Type  Number of Students         Budget  \
# 8   Cabrera High School  Charter                1858  $1,081,356.00
# 11   Thomas High School  Charter                1635  $1,043,130.00
# 13     Pena High School  Charter                 962    $585,858.00
# 12  Griffin High School  Charter                1468    $917,500.00
# 7    Wilson High School  Charter                2283  $1,319,574.00
#
#     Average Math Score  Average Reading Score  % Passing Math  \
# 8            83.061895              83.975780       94.133477
# 11           83.418349              83.848930       93.272171
# 13           83.839917              84.044699       94.594595
# 12           83.351499              83.816757       93.392371
# 7            83.274201              83.989488       93.867718
#
#     Reading Passing %  Overall Passing %
# 8           97.039828          95.586652
# 11          97.308869          95.290520
# 13          95.945946          95.270270
# ...

# %%
bottomSchools=schoolSummary.sort_values(["Overall Passing %"], ascending=True)

# %%
bottomSchools.head(5)
# Out:
#              School Name      Type  Number of Students         Budget  \
# 3  Rodriguez High School  District                3999  $2,547,363.00
# 4   Figueroa High School  District                2949  $1,884,411.00
# 5      Huang High School  District                2917  $1,910,635.00
# 1    Johnson High School  District                4761  $3,094,650.00
# 6       Ford High School  District                2739  $1,763,916.00
#
#    Average Math Score  Average Reading Score  % Passing Math  \
# 3           76.842711              80.744686       66.366592
# 4           76.711767              81.158020       65.988471
# 5           76.629414              81.182722       65.683922
# 1           77.072464              80.966394       66.057551
# 6           77.102592              80.746258       68.309602
#
#    Reading Passing %  Overall Passing %
# 3          80.220055          73.293323
# 4          80.739234          73.363852
# 5          81.316421          73.500171
# ...

# %%
studentData
# Out:
#        Student ID         student_name gender grade         school_name  \
# 0               0         Paul Bradley      M   9th   Huang High School
# 1               1         Victor Smith      M  12th   Huang High School
# 2               2      Kevin Rodriguez      M  12th   Huang High School
# 3               3    Dr. Richard Scott      M  12th   Huang High School
# 4               4           Bonnie Ray      F   9th   Huang High School
# 5               5        Bryan Miranda      M   9th   Huang High School
# 6               6        Sheena Carter      F  11th   Huang High School
# 7               7         Nicole Baker      F  12th   Huang High School
# 8               8         Michael Roth      M  10th   Huang High School
# 9               9       Matthew Greene      M  10th   Huang High School
# 10             10     Andrew Alexander      M  10th   Huang High School
# 11             11        Daniel Cooper      M  10th   Huang High School
# ...

# %%
nine=studentData.loc[(studentData['grade']== '9th')]
ninethMath=nine[['school_name','grade','math_score']]

# %%
#readPassingbySchool=readPassingbySchool.groupby(['school_name']).count()
averageMathbyGrade=ninethMath.groupby('school_name').mean()

# %%
averageMathbyGrade.head(2)
# Out:
#                            9th
# school_name
# Bailey High School   77.083676
# Cabrera High School  83.094697

# %%
averageMathbyGrade=averageMathbyGrade.rename(columns={'math_score':'9th'})

# %%
tenthMath=studentData.loc[(studentData['grade']== '10th')]

# %%
tenthMath=tenthMath[['school_name','grade','math_score']]
tenthMath.head()
# Out:
#           school_name grade  math_score
# 8   Huang High School  10th          87
# 9   Huang High School  10th          84
# 10  Huang High School  10th          70
# 11  Huang High School  10th          77
# 14  Huang High School  10th          67

# %%
tenthMath=tenthMath.groupby('school_name').mean()
tenthMath.head(2)
# Out:
#                      math_score
# school_name
# Bailey High School    76.996772
# Cabrera High School   83.154506

# %%
tenthMath=tenthMath.rename(columns={'math_score':'10th'})
tenthMath
# Out:
#                             10th
# school_name
# Bailey High School     76.996772
# Cabrera High School    83.154506
# Figueroa High School   76.539974
# Ford High School       77.672316
# Griffin High School    84.229064
# Hernandez High School  77.337408
# Holden High School     83.429825
# Huang High School      75.908735
# Johnson High School    76.691117
# Pena High School       83.372000
# Rodriguez High School  76.612500
# Shelton High School    82.917411
# Thomas High School     83.087886
# Wilson High School     83.724422
# Wright High School     84.010288

# %%
averageMathbyGrade=averageMathbyGrade.merge(tenthMath, left_on='school_name', right_on='school_name', how='inner')
# Out:
#                             9th     10th_x     10th_y
# school_name
# Bailey High School    77.083676  76.996772  76.996772
# Cabrera High School   83.094697  83.154506  83.154506
# Figueroa High School  76.403037  76.539974  76.539974

# %%
#schoolSummary=schoolSummary.drop('school_name',axis=1)
averageMathbyGrade=averageMathbyGrade.drop('10th_y', axis=1)

# %%
averageMathbyGrade=averageMathbyGrade.rename(columns={'10th_x':'10th'})

# %%
averageMathbyGrade.head()
# Out:
#                             9th       10th
# school_name
# Bailey High School    77.083676  76.996772
# Cabrera High School   83.094697  83.154506
# Figueroa High School  76.403037  76.539974
# Ford High School      77.361345  77.672316
# Griffin High School   82.044010  84.229064

# %%
elevenMath=studentData.loc[(studentData['grade']== '11th')]

# %%
elevenMath.head()
# Out:
#     Student ID       student_name gender grade        school_name  \
# 6            6      Sheena Carter      F  11th  Huang High School
# 15          15  Dr. Jordan Carson      M  11th  Huang High School
# 22          22   Kimberly Stewart      F  11th  Huang High School
# 24          24   Chelsea Griffith      F  11th  Huang High School
# 28          28        Kelly James      F  11th  Huang High School
#
#     reading_score  math_score
# 6              82          80
# 15             94          88
# 22             99          84
# 24             85          73
# 28             73          55

# %%
eleventhMath=elevenMath[['school_name','grade','math_score']]
eleventhMath.head()
# Out:
#           school_name grade  math_score
# 6   Huang High School  11th          80
# 15  Huang High School  11th          88
# 22  Huang High School  11th          84
# 24  Huang High School  11th          73
# 28  Huang High School  11th          55

# %%
eleventhMath=eleventhMath.groupby('school_name').mean()
eleventhMath.head(2)
# Out:
#                      math_score
# school_name
# Bailey High School    77.515588
# Cabrera High School   82.765560

# %%
eleventhMath=eleventhMath.rename(columns={'math_score':'11th'})
eleventhMath
# Out:
#                             11th
# school_name
# Bailey High School     77.515588
# Cabrera High School    82.765560
# Figueroa High School   76.884344
# Ford High School       76.918058
# Griffin High School    83.842105
# Hernandez High School  77.136029
# Holden High School     85.000000
# Huang High School      76.446602
# Johnson High School    77.491653
# Pena High School       84.328125
# Rodriguez High School  76.395626
# Shelton High School    83.383495
# Thomas High School     83.498795
# Wilson High School     83.195326
# Wright High School     83.836782

# %%
averageMathbyGrade=averageMathbyGrade.merge(eleventhMath, left_on='school_name', right_on='school_name', how='inner')
averageMathbyGrade
# Out:
#                              9th       10th       11th
# school_name
# Bailey High School     77.083676  76.996772  77.515588
# Cabrera High School    83.094697  83.154506  82.765560
# Figueroa High School   76.403037  76.539974  76.884344
# Ford High School       77.361345  77.672316  76.918058
# Griffin High School    82.044010  84.229064  83.842105
# Hernandez High School  77.438495  77.337408  77.136029
# Holden High School     83.787402  83.429825  85.000000
# Huang High School      77.027251  75.908735  76.446602
# Johnson High School    77.187857  76.691117  77.491653
# Pena High School       83.625455  83.372000  84.328125
# Rodriguez High School  76.859966  76.612500  76.395626
# Shelton High School    83.420755  82.917411  83.383495
# Thomas High School     83.590022  83.087886  83.498795
# Wilson High School     83.085578  83.724422  83.195326
# Wright High School     83.264706  84.010288  83.836782

# %%
twelthMath=studentData.loc[(studentData['grade']== '12th')]

# %%
twelthMath=twelthMath[['school_name','grade','math_score']]
twelthMath.head()
# Out:
#           school_name grade  math_score
# 1   Huang High School  12th          61
# 2   Huang High School  12th          60
# 3   Huang High School  12th          58
# 7   Huang High School  12th          69
# 29  Huang High School  12th          88

# %%
twelthMath=twelthMath.groupby('school_name').mean()
twelthMath.head(2)
# Out:
#                      math_score
# school_name
# Bailey High School    76.492218
# Cabrera High School   83.277487

# %%
twelthMath=twelthMath.rename(columns={'math_score':'12th'})
twelthMath.head()
# Out:
#                            12th
# school_name
# Bailey High School    76.492218
# Cabrera High School   83.277487
# Figueroa High School  77.151369
# Ford High School      76.179963
# Griffin High School   83.356164

# %%
averageMathbyGrade=averageMathbyGrade.merge(twelthMath, left_on='school_name', right_on='school_name', how='inner')
averageMathbyGrade
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# Thomas High School     83.590022  83.087886  83.498795  83.497041
# ...

# %%
#start reading; can reuse previous dfs
ninethRead=nine[['school_name','grade','reading_score']]
ninethRead.head()
# Out:
#           school_name grade  reading_score
# 0   Huang High School   9th             66
# 4   Huang High School   9th             97
# 5   Huang High School   9th             94
# 12  Huang High School   9th             64
# 13  Huang High School   9th             71

# %%
ninethRead=ninethRead.groupby('school_name').mean()
ninethRead.head(2)
# Out:
#                      reading_score
# school_name
# Bailey High School       81.303155
# Cabrera High School      83.676136

# %%
ninethRead=ninethRead.rename(columns={'reading_score':'9th'})
ninethRead.head(3)
# Out:
#                             9th
# school_name
# Bailey High School    81.303155
# Cabrera High School   83.676136
# Figueroa High School  81.198598

# %%
averageReadbyGrade=ninethRead

# %%
# Out:
#                              9th
# school_name
# Bailey High School     81.303155
# Cabrera High School    83.676136
# Figueroa High School   81.198598
# Ford High School       80.632653
# Griffin High School    83.369193
# Hernandez High School  80.866860
# Holden High School     83.677165
# Huang High School      81.290284
# Johnson High School    81.260714
# Pena High School       83.807273
# Rodriguez High School  80.993127
# Shelton High School    84.122642
# Thomas High School     83.728850
# Wilson High School     83.939778
# Wright High School     83.833333

# %%
tenthRead=studentData.loc[(studentData['grade']== '10th')]

# %%
tenthRead=tenthRead[['school_name','grade','reading_score']]

# %%
tenthRead=tenthRead.groupby('school_name').mean()
tenthRead.head(2)
# Out:
#                      reading_score
# school_name
# Bailey High School       80.907183
# Cabrera High School      84.253219

# %%
tenthRead=tenthRead.rename(columns={'reading_score':'10th'})
tenthRead.head(3)
# Out:
#                            10th
# school_name
# Bailey High School    80.907183
# Cabrera High School   84.253219
# Figueroa High School  81.408912

# %%
averageReadbyGrade=averageReadbyGrade.merge(tenthRead, left_on='school_name', right_on='school_name', how='inner')
averageReadbyGrade
# Out:
#                              9th       10th
# school_name
# Bailey High School     81.303155  80.907183
# Cabrera High School    83.676136  84.253219
# Figueroa High School   81.198598  81.408912
# Ford High School       80.632653  81.262712
# Griffin High School    83.369193  83.706897
# Hernandez High School  80.866860  80.660147
# Holden High School     83.677165  83.324561
# Huang High School      81.290284  81.512386
# Johnson High School    81.260714  80.773431
# Pena High School       83.807273  83.612000
# Rodriguez High School  80.993127  80.629808
# Shelton High School    84.122642  83.441964
# Thomas High School     83.728850  84.254157
# Wilson High School     83.939778  84.021452
# Wright High School     83.833333  83.812757

# %%
eleventhRead=studentData.loc[(studentData['grade']== '11th')]

# %%
eleventhRead=eleventhRead[['school_name','grade','reading_score']]

# %%
eleventhRead=eleventhRead.groupby('school_name').mean()
eleventhRead.head(2)
# Out:
#                      reading_score
# school_name
# Bailey High School       80.945643
# Cabrera High School      83.788382

# %%
eleventhRead=eleventhRead.rename(columns={'reading_score':'11th'})
eleventhRead.head(3)
# Out:
#                            11th
# school_name
# Bailey High School    80.945643
# Cabrera High School   83.788382
# Figueroa High School  80.640339

# %%
averageReadbyGrade=averageReadbyGrade.merge(eleventhRead, left_on='school_name', right_on='school_name', how='inner')
averageReadbyGrade
# Out:
#                              9th       10th       11th
# school_name
# Bailey High School     81.303155  80.907183  80.945643
# Cabrera High School    83.676136  84.253219  83.788382
# Figueroa High School   81.198598  81.408912  80.640339
# Ford High School       80.632653  81.262712  80.403642
# Griffin High School    83.369193  83.706897  84.288089
# Hernandez High School  80.866860  80.660147  81.396140
# Holden High School     83.677165  83.324561  83.815534
# Huang High School      81.290284  81.512386  81.417476
# Johnson High School    81.260714  80.773431  80.616027
# Pena High School       83.807273  83.612000  84.335938
# Rodriguez High School  80.993127  80.629808  80.864811
# Shelton High School    84.122642  83.441964  84.373786
# Thomas High School     83.728850  84.254157  83.585542
# Wilson High School     83.939778  84.021452  83.764608
# Wright High School     83.833333  83.812757  84.156322

# %%
twelthRead=studentData.loc[(studentData['grade']== '12th')]

# %%
twelthRead=twelthRead[['school_name','grade','reading_score']]

# %%
twelthRead=twelthRead.groupby('school_name').mean()
twelthRead.head(2)
# Out:
#                      reading_score
# school_name
# Bailey High School       80.912451
# Cabrera High School      84.287958

# %%
twelthRead=twelthRead.rename(columns={'reading_score':'12th'})
twelthRead.head(3)
# Out:
#                            12th
# school_name
# Bailey High School    80.912451
# Cabrera High School   84.287958
# Figueroa High School  81.384863

# %%
averageReadbyGrade=averageReadbyGrade.merge(twelthRead, left_on='school_name', right_on='school_name', how='inner')
averageReadbyGrade
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     81.303155  80.907183  80.945643  80.912451
# Cabrera High School    83.676136  84.253219  83.788382  84.287958
# Figueroa High School   81.198598  81.408912  80.640339  81.384863
# Ford High School       80.632653  81.262712  80.403642  80.662338
# Griffin High School    83.369193  83.706897  84.288089  84.013699
# Hernandez High School  80.866860  80.660147  81.396140  80.857143
# Holden High School     83.677165  83.324561  83.815534  84.698795
# Huang High School      81.290284  81.512386  81.417476  80.305983
# Johnson High School    81.260714  80.773431  80.616027  81.227564
# Pena High School       83.807273  83.612000  84.335938  84.591160
# Rodriguez High School  80.993127  80.629808  80.864811  80.376426
# Shelton High School    84.122642  83.441964  84.373786  82.781671
# Thomas High School     83.728850  84.254157  83.585542  83.831361
# ...

# %%
schoolData.head()
# Out:
#    School ID            school_name      type  size   budget
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500

# %%
schoolData['budget']*.001
# Out:
# 0     1910.635
# 1     1884.411
# 2     1056.600
# 3     3022.020
# 4      917.500
# 5     1319.574
# 6     1081.356
# 7     3124.928
# 8      248.087
# 9      585.858
# 10    1049.400
# 11    2547.363
# 12    3094.650
# 13    1763.916
# 14    1043.130
# Name: budget, dtype: float64

# %%
   # Sample bins. Feel free to create your own bins.
spending_bins = [0, 585, 615, 645, 675]
group_names = ["<$585", "$585-615", "$615-645", "$645-675"]

# %%
#Average Math Score, Average Reading Score, % Passing Math,% Passing Reading,Overall Passing Rate (Average of the above two)
#'Average Math Score', 'Average Reading Score','% Passing Math', 'Reading Passing %', 'Overall Passing %'

performanceFunding=schoolSummary[['Average Math Score', 'Average Reading Score','% Passing Math', 'Reading Passing %', 'Overall Passing %','$ Per Student Budget']]

# %%
performanceFunding=performanceFunding.rename(columns={'costPerStudent':'$ Per Student Budget'})

# %%
performanceFunding
# Out:
#     Average Math Score  Average Reading Score  % Passing Math  \
# 0            77.048432              81.033963       66.680064
# 1            77.072464              80.966394       66.057551
# 2            77.289752              80.934412       66.752967
# 3            76.842711              80.744686       66.366592
# 4            76.711767              81.158020       65.988471
# 5            76.629414              81.182722       65.683922
# 6            77.102592              80.746258       68.309602
# 7            83.274201              83.989488       93.867718
# 8            83.061895              83.975780       94.133477
# 9            83.682222              83.955000       93.333333
# 10           83.359455              83.725724       93.867121
# 11           83.418349              83.848930       93.272171
# 12           83.351499              83.816757       93.392371
# 13           83.839917              84.044699       94.594595
# ...

# %%
#df["Test Score Summary"] = pd.cut(df["Test Score"], bins, labels=group_names)
#fmi.loc[:,('one','second')]
performanceFunding['Spending Ranges Per Student']=pd.cut(performanceFunding.loc[:,('$ Per Student Budget')], spending_bins,labels=group_names)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
performanceFunding
# Out:
#     Average Math Score  Average Reading Score  % Passing Math  \
# 0            77.048432              81.033963       66.680064
# 1            77.072464              80.966394       66.057551
# 2            77.289752              80.934412       66.752967
# 3            76.842711              80.744686       66.366592
# 4            76.711767              81.158020       65.988471
# 5            76.629414              81.182722       65.683922
# 6            77.102592              80.746258       68.309602
# 7            83.274201              83.989488       93.867718
# 8            83.061895              83.975780       94.133477
# 9            83.682222              83.955000       93.333333
# 10           83.359455              83.725724       93.867121
# 11           83.418349              83.848930       93.272171
# 12           83.351499              83.816757       93.392371
# 13           83.839917              84.044699       94.594595
# ...

# %%
performanceFunding=performanceFunding.drop('Spending Ranges Per Student',axis=1)

# %%
performanceFunding

# %%
#df = df.groupby("Test Score Summary")
performanceFunding=performanceFunding.groupby('Spending Ranges Per Student')

# %%
performanceFunding.max() # these numbers don't match the example?
# Out:
#                              Average Math Score  Average Reading Score  \
# Spending Ranges Per Student
# <$585                                 83.803279              83.989488
# $585-615                              83.839917              84.044699
# $615-645                              83.418349              83.848930
# $645-675                              77.289752              81.182722
#
#                              % Passing Math  Reading Passing %  \
# Spending Ranges Per Student
# <$585                             94.133477          97.039828
# $585-615                          94.594595          95.945946
# $615-645                          93.392371          97.308869
# $645-675                          66.752967          81.316421
#
#                              Overall Passing %  $ Per Student Budget
# Spending Ranges Per Student
# <$585                                95.586652                 583.0
# ...

# %%
#performanceSize, Number of Students
size_bins = [0, 1000, 2000, 5000]
group_names = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]

# %%
performanceSize=schoolSummary[['Average Math Score', 'Average Reading Score','% Passing Math', 'Reading Passing %', 'Overall Passing %','Number of Students']]

# %%
performanceSize
# Out:
#     Average Math Score  Average Reading Score  % Passing Math  \
# 0            77.048432              81.033963       66.680064
# 1            77.072464              80.966394       66.057551
# 2            77.289752              80.934412       66.752967
# 3            76.842711              80.744686       66.366592
# 4            76.711767              81.158020       65.988471
# 5            76.629414              81.182722       65.683922
# 6            77.102592              80.746258       68.309602
# 7            83.274201              83.989488       93.867718
# 8            83.061895              83.975780       94.133477
# 9            83.682222              83.955000       93.333333
# 10           83.359455              83.725724       93.867121
# 11           83.418349              83.848930       93.272171
# 12           83.351499              83.816757       93.392371
# 13           83.839917              84.044699       94.594595
# ...

# %%
performanceSize['School Size']=pd.cut(performanceSize.loc[('Number of Students')], size_bins,labels=group_names)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1789                 if not ax.contains(key):
# -> 1790                     error()
#    1791             except TypeError as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in error()
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#
# KeyError: 'the label [Number of Students] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-328-e3b09e2517d8> in <module>()
# ...

# %%
#schoolSummary=schoolSummary.drop('school_name',axis=1)
#performanceSize=performanceSize.drop('Number of Students', axis=1)
performanceSize

# %%
performanceSize=performanceSize.groupby('School Size')
performanceSize.max()
# Out:
#                     Average Math Score  Average Reading Score  % Passing Math  \
# School Size
# Small (<1000)                83.839917              84.044699       94.594595
# Medium (1000-2000)           83.682222              83.975780       94.133477
# Large (2000-5000)            83.274201              83.989488       93.867718
#
#                     Reading Passing %  Overall Passing %  Number of Students
# School Size
# Small (<1000)               96.252927          95.270270                 962
# Medium (1000-2000)          97.308869          95.586652                1858
# Large (2000-5000)           96.539641          95.203679                4976

# %%
#scores by school type
type_bins = ['Charter','District']
group_names = ["Charter", "District"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-355-8295b3e50616> in <module>()
#       1 #scores by school type
# ----> 2 type_bins = [Charter,District]
#       3 group_names = ["Charter", "District"]
#
# NameError: name 'Charter' is not defined

# %%
performanceType=schoolSummary[['Average Math Score', 'Average Reading Score','% Passing Math', 'Reading Passing %', 'Overall Passing %','Type']]

# %%
# Out:
#     Average Math Score  Average Reading Score  % Passing Math  \
# 0            77.048432              81.033963       66.680064
# 1            77.072464              80.966394       66.057551
# 2            77.289752              80.934412       66.752967
# 3            76.842711              80.744686       66.366592
# 4            76.711767              81.158020       65.988471
# 5            76.629414              81.182722       65.683922
# 6            77.102592              80.746258       68.309602
# 7            83.274201              83.989488       93.867718
# 8            83.061895              83.975780       94.133477
# 9            83.682222              83.955000       93.333333
# 10           83.359455              83.725724       93.867121
# 11           83.418349              83.848930       93.272171
# 12           83.351499              83.816757       93.392371
# 13           83.839917              84.044699       94.594595
# ...

# %%
#performanceSize=performanceSize.groupby('School Size')
performanceType=performanceType.groupby('Type')

# %%
performanceType.max()
# Out:
#           Average Math Score  Average Reading Score  % Passing Math  \
# Type
# Charter            83.839917              84.044699       94.594595
# District           77.289752              81.182722       68.309602
#
#           Reading Passing %  Overall Passing %
# Type
# Charter           97.308869          95.586652
# District          81.933280          74.306672
